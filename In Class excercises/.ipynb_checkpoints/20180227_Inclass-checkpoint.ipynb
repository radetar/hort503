# %%
import pandas as pd

isolate = pd.read_table("PI_DataSet.txt", sep="\t")
isolate
# Out:
#        SeqID   FPV   ATV   IDV   LPV    NFV     SQV  TPV  DRV P1 ... P90 P91  \
# 0       2996   2.5   NaN  16.3   NaN   38.6    16.1  NaN  NaN  - ...   M   -
# 1       4387   0.7   NaN   0.8   NaN    0.8     1.1  NaN  NaN  - ...   -   -
# 2       4426   3.0  32.0  35.0  32.0   29.0   164.0  NaN  NaN  . ...   -   -
# 3       4432   1.5   NaN   1.0   NaN    2.2     1.1  NaN  NaN  - ...   -   -
# 4       4482   3.9   NaN  20.2   NaN   21.6     9.2  NaN  NaN  - ...   M   -
# 5       4486   9.5  20.0   8.2  11.0   72.0    46.0  NaN  NaN  - ...   -   -
# 6       4538   NaN   NaN  21.0   7.5   55.0    85.0  NaN  NaN  - ...   M   -
# 7       4664   3.1   NaN   8.7   NaN   32.0    16.9  NaN  NaN  - ...   M   -
# 8       4690   4.9  15.0  18.0   5.9   24.0    73.0  NaN  NaN  - ...   M   -
# 9       4698   1.2   NaN   0.7   NaN    3.6     1.3  NaN  NaN  - ...   -   -
# 10      5221   NaN   NaN   0.8   0.8    1.2     0.7  NaN  NaN  - ...   -   -
# ...

# %%
#isolate["SeqID"]=isolate.index
#isolate
# Out:
#       SeqID   FPV   ATV   IDV   LPV    NFV     SQV  TPV  DRV P1  ...   P91  \
# 0         0   2.5   NaN  16.3   NaN   38.6    16.1  NaN  NaN  -  ...     -
# 1         1   0.7   NaN   0.8   NaN    0.8     1.1  NaN  NaN  -  ...     -
# 2         2   3.0  32.0  35.0  32.0   29.0   164.0  NaN  NaN  .  ...     -
# 3         3   1.5   NaN   1.0   NaN    2.2     1.1  NaN  NaN  -  ...     -
# 4         4   3.9   NaN  20.2   NaN   21.6     9.2  NaN  NaN  -  ...     -
# 5         5   9.5  20.0   8.2  11.0   72.0    46.0  NaN  NaN  -  ...     -
# 6         6   NaN   NaN  21.0   7.5   55.0    85.0  NaN  NaN  -  ...     -
# 7         7   3.1   NaN   8.7   NaN   32.0    16.9  NaN  NaN  -  ...     -
# 8         8   4.9  15.0  18.0   5.9   24.0    73.0  NaN  NaN  -  ...     -
# 9         9   1.2   NaN   0.7   NaN    3.6     1.3  NaN  NaN  -  ...     -
# 10       10   NaN   NaN   0.8   0.8    1.2     0.7  NaN  NaN  -  ...     -
# ...

# %%
aa_pos = isolate.loc[:,'P1':'P99']
aa_pos["SeqID"]=isolate["SeqID"]
aa_pos
# Out:
#      P1 P2  P3 P4 P5 P6 P7 P8 P9 P10   ...   P91 P92 P93 P94 P95 P96 P97 P98  \
# 0     -  -   -  -  -  -  -  -  -   I   ...     -   -   L   -   -   -   -   -
# 1     -  -   -  -  -  -  -  -  -   -   ...     -   -   -   -   -   -   -   -
# 2     .  .   .  .  .  .  .  .  .   I   ...     -   -   L   -   -   -   -   -
# 3     -  -   -  -  -  -  -  -  -   -   ...     -   -   -   -   -   -   -   -
# 4     -  -   -  -  -  -  -  -  -   V   ...     -   -   L   -   -   -   -   -
# 5     -  -   -  -  -  -  -  -  -   F   ...     -   -   -   -   -   -   -   -
# 6     -  -   -  -  -  -  -  -  -   I   ...     -   -   -   -   -   -   -   -
# 7     -  -   -  -  -  -  -  -  -   I   ...     -   -   -   -   -   -   -   -
# 8     -  -   -  -  -  -  -  -  -   I   ...     -   -   -   -   -   -   -   -
# 9     -  -   -  -  -  -  -  -  -   -   ...     -   -   L   -   -   -   -   -
# 10    -  -   -  -  -  -  -  -  -   -   ...     -   -   -   -   -   -   -   -
# ...

# %%
aa_pos_tidy = pd.melt(aa_pos, id_vars="SeqID", value_name="AA", var_name = "AA_pos")
# aa_pos_tidy = pd.to_numeric(aa_pos_tidy["AA_pos"])
aa_pos_tidy.head(5)
# Out:
#    SeqID AA_pos AA
# 0   2996     P1  -
# 1   4387     P1  -
# 2   4426     P1  .
# 3   4432     P1  -
# 4   4482     P1  -

# %%
aa_pos_tidy = aa_pos_tidy.sort_values(["SeqID", "AA_pos"],ascending=True)
aa_pos_tidy.reset_index()
aa_pos_tidy.head()
# Out:
#        SeqID AA_pos AA
# 0       2996     P1  -
# 16272   2996    P10  I
# 18080   2996    P11  -
# 19888   2996    P12  -
# 21696   2996    P13  -
